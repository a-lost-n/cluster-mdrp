# %%
from src import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# 2023-11-22 18:54:41.860522: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
episodios=1000
episodios_terminados=0
decay=0.997
limit=150

# %%
agent = Agent(map_file="0o100t100s1p100", name='models/m7_n4', num_clusters=4, pre_train=True, model=model7)
agent.train(episodes=episodios, finished_episodes=episodios_terminados, batch_size=32, epsilon=1,
             epsilon_decay=decay, score_limit=limit, refresh_rate=2, verbose=False, 
             block_impossible_actions=True)
# Out:
# 2023-11-22 18:56:04.075781: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 12. Tune using inter_op_parallelism_threads for best performance.
# episode: 1/1000, score: 77.33, e: 1.00, actions: 137, couriers: 71, orders: 596, t: 0.08s
# [TEST] score: 150.98, actions: 275, couriers: 141, orders: 6, t: 10.84s
# episode: 2/1000, score: 71.49, e: 1.00, actions: 126, couriers: 66, orders: 577, t: 0.07s
# [TEST] score: 150.35, actions: 279, couriers: 140, orders: 2, t: 10.96s
# episode: 3/1000, score: 45.41, e: 0.99, actions: 79, couriers: 42, orders: 576, t: 0.06s
# [TEST] score: 150.30, actions: 174, couriers: 147, orders: 6, t: 6.93s
# episode: 4/1000, score: 49.26, e: 0.99, actions: 89, couriers: 45, orders: 596, t: 0.07s
# [TEST] score: 150.00, actions: 150, couriers: 150, orders: 1, t: 5.94s
# episode: 5/1000, score: 55.46, e: 0.99, actions: 90, couriers: 52, orders: 601, t: 0.14s
# ...

# %%
agent.map.display_map_clusters()

# %% [markdown]
# ## Modelo 1
# Input(12)->ReLU(576)->ReLU(192)->ReLU(64)->Linear(16)

# %%
def model1():
    model=Sequential()
    model.add(Dense(576,input_dim=12, activation='relu'))
    model.add(Dense(192, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(16, activation='linear'))
    return model

# %%
agent = Agent(map_file="0o100t100s1p100", filename="models/m1_n4", num_clusters=4, pre_train=False, model=model1)
agent.test(episodes=200, score_limit=250)
# Out:
# 2023-10-31 09:13:39.037963: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 12. Tune using inter_op_parallelism_threads for best performance.
# Percentil 50: 72.65076761853891
# Percentil 75: 113.9382289180454
# Percentil 90: 250.3075620941868
# Percentil 95: 250.7346155961378

# %% [markdown]
# # Modelo 2
# Input(12)->ReLU(384)->ReLU(192)->ReLU(96)->Linear(16)

# %%
def model2():
    model=Sequential()
    model.add(Dense(384,input_dim=12, activation='relu'))
    model.add(Dense(192, activation='relu'))
    model.add(Dense(96, activation='relu'))
    model.add(Dense(16, activation='linear'))
    return model

# %%
agent = Agent(map_file="0o100t100s1p100", filename="models/m2_n4", num_clusters=4, pre_train=False, model=model2)
agent.test(episodes=200, score_limit=250)
# Out:
# 2023-11-01 08:36:16.575445: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 12. Tune using inter_op_parallelism_threads for best performance.
# Percentil 50: 94.72642426753083
# Percentil 75: 250.45599911508074
# Percentil 90: 250.77862525670415
# Percentil 95: 250.82385359945278

# %% [markdown]
# ## Modelo 3
# Input(12)->ReLU(192)->ReLU(128)->ReLU(64)->Linear(16)

# %%
def model3():
    model=Sequential()
    model.add(Dense(192,input_dim=12, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(16, activation='linear'))
    return model

# %%
agent = Agent(map_file="0o100t100s1p100", filename="models/m3_n4", num_clusters=4, pre_train=False, model=model3)
agent.test(episodes=200, score_limit=250)
# Out:
# Percentil 50: 78.94799523122555
# Percentil 75: 250.03526623538116
# Percentil 90: 250.60900892694696
# Percentil 95: 250.77822514083454

# %% [markdown]
# ## Modelo 4
# Input(12)->ReLU(192)->ReLU(128)->ReLU(64)->ReLU(32)->Linear(16)

# %%
def model4():
    model=Sequential()
    model.add(Dense(192,input_dim=12, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(16, activation='linear'))
    return model

# %%
agent = Agent(map_file="0o100t100s1p100", filename="models/m4_n4", num_clusters=4, pre_train=False, model=model4)
agent.test(episodes=200, score_limit=250)
# Out:
# 2023-11-01 09:26:13.105185: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 12. Tune using inter_op_parallelism_threads for best performance.
# Percentil 50: 96.31564475151073
# Percentil 75: 133.53622927365703
# Percentil 90: 236.77589594198412
# Percentil 95: 250.5230057164079

# %% [markdown]
# ## Modelo 5
# Input(12)->ReLU(128)->ReLU(128)->Linear(16)

# %%
def model5():
    model=Sequential()
    model.add(Dense(128,input_dim=12, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(16, activation='linear'))
    return model

# %%
agent = Agent(map_file="0o100t100s1p100", filename="models/m5_n4", num_clusters=4, pre_train=False, model=model5)
agent.test(episodes=200, score_limit=250)
# Out:
# Percentil 50: 83.51830542260245
# Percentil 75: 111.30200285157636
# Percentil 90: 162.96130955900176
# Percentil 95: 208.3602588258902

# %% [markdown]
# ## Modelo 6
# Input(12)->ReLU(192)->ReLU(192)->Linear(16)

# %%
def model6():
    model=Sequential()
    model.add(Dense(192,input_dim=12, activation='relu'))
    model.add(Dense(192, activation='relu'))
    model.add(Dense(16, activation='linear'))
    return model

# %%
agent = Agent(map_file="0o100t100s1p100", filename="models/m6_n4", num_clusters=4, pre_train=False, model=model6)
agent.test(episodes=200, score_limit=250)
# Out:
# Percentil 50: 49.78024825027513
# Percentil 75: 149.4739770202966
# Percentil 90: 250.31846605628903
# Percentil 95: 250.47751076601858

# %% [markdown]
# ## Modelo 7
# Input(12)->ReLU(96)->ReLU(96)->Linear(16)

# %%
def model7():
    model=Sequential()
    model.add(Dense(96,input_dim=12, activation='relu'))
    model.add(Dense(96, activation='relu'))
    model.add(Dense(16, activation='linear'))
    return model

# %%
agent = Agent(map_file="0o100t100s1p100", filename="models/m7_n4", num_clusters=4, pre_train=False, model=model7)
# agent.test(episodes=200, score_limit=250)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 agent = Agent(map_file="0o100t100s1p100", filename="models/m7_n4", num_clusters=4, pre_train=False, model=model7)
#       2 agent.test(episodes=200, score_limit=250)
#
# File ~/Tesis/cluster-mdrp/src/agent.py:25, in Agent.__init__(self, restaurant_array, learning_rate, grid_size, randseed, map_file, filename, num_clusters, pre_train, name, model)
#      23 def __init__(self, restaurant_array=None, learning_rate=0.001, grid_size=100, randseed=0, map_file=None, filename=None,
#      24              num_clusters=None, pre_train=True, name=None, model=None):
# ---> 25     self.map = Map(restaurant_array=restaurant_array,
#      26                    grid_size=grid_size, randseed=randseed, import_dir=map_file,
#      27                    num_clusters=num_clusters, filename=filename)
# ...

# %%
agent.train(episodes=episodios, finished_episodes=episodios_terminados, batch_size=32, epsilon=1,
            epsilon_decay=0.997, score_limit=limit, refresh_rate=2, verbose=False, 
            block_impossible_actions=True, log=True, run_test=False)
